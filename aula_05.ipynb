# %%
import pandas as pd
import seaborn as sns

# %%
df = pd.read_csv(r".\data\dataset_aula03_student_habits_performance.csv")

# %%
df
# Out:
#     student_id  age  gender  study_hours_per_day  social_media_hours  \
# 0        S1000   23  Female                  0.0                 1.2
# 1        S1001   20  Female                  6.9                 2.8
# 2        S1002   21    Male                  1.4                 3.1
# 3        S1003   23  Female                  1.0                 3.9
# 4        S1004   19  Female                  5.0                 4.4
# ..         ...  ...     ...                  ...                 ...
# 995      S1995   21  Female                  2.6                 0.5
# 996      S1996   17  Female                  2.9                 1.0
# 997      S1997   20    Male                  3.0                 2.6
# 998      S1998   24    Male                  5.4                 4.1
# 999      S1999   19  Female                  4.3                 2.9
#
#      netflix_hours part_time_job  attendance_percentage  sleep_hours  \
# ...

# %%
df.head()
# Out:
#   student_id  age  gender  study_hours_per_day  social_media_hours  \
# 0      S1000   23  Female                  0.0                 1.2
# 1      S1001   20  Female                  6.9                 2.8
# 2      S1002   21    Male                  1.4                 3.1
# 3      S1003   23  Female                  1.0                 3.9
# 4      S1004   19  Female                  5.0                 4.4
#
#    netflix_hours part_time_job  attendance_percentage  sleep_hours  \
# 0            1.1            No                   85.0          8.0
# 1            2.3            No                   97.3          4.6
# 2            1.3            No                   94.8          8.0
# 3            1.0            No                   71.0          9.2
# 4            0.5            No                   90.9          4.9
#
#   diet_quality  exercise_frequency parental_education_level internet_quality  \
# 0         Fair                   6                   Master          Average
# ...

# %%
df.shape
# Out:
# (1000, 16)

# %%
df.tail()
# Out:
#     student_id  age  gender  study_hours_per_day  social_media_hours  \
# 995      S1995   21  Female                  2.6                 0.5
# 996      S1996   17  Female                  2.9                 1.0
# 997      S1997   20    Male                  3.0                 2.6
# 998      S1998   24    Male                  5.4                 4.1
# 999      S1999   19  Female                  4.3                 2.9
#
#      netflix_hours part_time_job  attendance_percentage  sleep_hours  \
# 995            1.6            No                   77.0          7.5
# 996            2.4           Yes                   86.0          6.8
# 997            1.3            No                   61.9          6.5
# 998            1.1           Yes                  100.0          7.6
# 999            1.9            No                   89.4          7.1
#
#     diet_quality  exercise_frequency parental_education_level  \
# 995         Fair                   2              High School
# ...

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 16 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   student_id                     1000 non-null   str
#  1   age                            1000 non-null   int64
#  2   gender                         1000 non-null   str
#  3   study_hours_per_day            1000 non-null   float64
#  4   social_media_hours             1000 non-null   float64
#  5   netflix_hours                  1000 non-null   float64
#  6   part_time_job                  1000 non-null   str
#  7   attendance_percentage          1000 non-null   float64
#  8   sleep_hours                    1000 non-null   float64
#  9   diet_quality                   1000 non-null   str
#  10  exercise_frequency             1000 non-null   int64
#  11  parental_education_level       909 non-null    str
#  12  internet_quality               1000 non-null   str
# ...

# %%
#Clean Code
valores_nulos = df["parental_education_level"].isna().sum()
print(f"A coluna de escolaridade dos pais possui {valores_nulos} dados desconhecidos.")
# Out:
# A coluna de escolaridade dos pais possui 91 dados desconhecidos.

# %%
valores_nao_nulos = df["parental_education_level"].notnull().sum()
print(f"A coluna de escolaridade dos pais possui {valores_nao_nulos} dados válidos.")
# Out:
# A coluna de escolaridade dos pais possui 909 dados válidos.

# %%
df.shape[0]
# Out:
# 1000

# %%
#O comando fillna preenche os valores NULOS.
df["parental_education_level"] = df["parental_education_level"].fillna("Desconhecido")
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 16 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   student_id                     1000 non-null   str
#  1   age                            1000 non-null   int64
#  2   gender                         1000 non-null   str
#  3   study_hours_per_day            1000 non-null   float64
#  4   social_media_hours             1000 non-null   float64
#  5   netflix_hours                  1000 non-null   float64
#  6   part_time_job                  1000 non-null   str
#  7   attendance_percentage          1000 non-null   float64
#  8   sleep_hours                    1000 non-null   float64
#  9   diet_quality                   1000 non-null   str
#  10  exercise_frequency             1000 non-null   int64
#  11  parental_education_level       1000 non-null   str
#  12  internet_quality               1000 non-null   str
# ...

# %%
#Mostra quais são os tipos de informações
df["parental_education_level"].unique()
# Out:
# <ArrowStringArray>
# ['Master', 'High School', 'Bachelor', 'Desconhecido']
# Length: 4, dtype: str

# %%
df["parental_education_level"].nunique()
# Out:
# 4

# %%
#Separando campos com números para gerar gráficos
colunas = ["age","study_hours_per_day","social_media_hours","netflix_hours","attendance_percentage","sleep_hours","exercise_frequency","mental_health_rating","exam_score"]

# %%
sns.heatmap(df[colunas].corr(),annot=True,fmt=".2f",cmap="coolwarm")
# Out:
# <Axes: >

# %% [markdown]
# Resultados do Gráfico acima:
#
# Quanto mais próximo do 1, maior será a relação e quanto mais próximo do -1 menor será a relação.
#
# 1 - A idade dos participantes do estudo é irrelevante para a nota do aluno.
# 2 - A quantidade de horas de estudo por dia influencia positivamente na nota do aluno.
# 3 - A quantidade de tempo em redes sociais influenciam negativamente na nota do aluno.
# 4 - A quantidade de horas de Netflix influenciam negativamente na nota do aluno.
# 5 - Quanto mais o aluno frequentar as aulas melhor a nota do aluno.
# 6 - Quanto mais o aluno dormir, maior será a nota dele.
# 7 - Quanto mais exercício físico o aluno fizer, maior será a nota dele.
# 8 - Quanto maior for a saúde mental do aluno, maior será a nota dele.

# %%
filtro_horas_altas = df["study_hours_per_day"] >= 5

filtro_horas_baixas = df["study_hours_per_day"] < 3

# %%
media_pessoas_estudam_muito = df[filtro_horas_altas]["exam_score"].mean()

media_pessoas_estudam_pouco = df[filtro_horas_baixas]["exam_score"].mean()

print(f"A média das notas de pessoas que estudam 5 ou mais horas por dia é de: {media_pessoas_estudam_muito:,.2f}")

print(f"A média das notas de pessoas que estudam menos de 3 horas por dia é de: {media_pessoas_estudam_pouco:,.2f}")
# Out:
# A média das notas de pessoas que estudam 5 ou mais horas por dia é de: 90.30
# A média das notas de pessoas que estudam menos de 3 horas por dia é de: 53.92

# %%
sns.lmplot(data=df,x="study_hours_per_day",y="exam_score");

# %%
sns.lmplot(data=df,x="netflix_hours",y="exam_score");

# %%
sns.lmplot(data=df,x="age",y="exam_score");

# %%
sns.lmplot(data=df,x="mental_health_rating",y="exam_score");
