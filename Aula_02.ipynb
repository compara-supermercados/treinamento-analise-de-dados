# %%
#Estruturas de Dados
temperaturas = [30,35,39,40,42,45,38,37]
print(temperaturas)
# Out:
# [30, 35, 39, 40, 42, 45, 38, 37]

# %%
print(temperaturas[0])
# Out:
# 30

# %%
print(temperaturas[1])
# Out:
# 35

# %%
print(f"O primeiro registro de temperatura foi de {temperaturas[0]} graus.")
# Out:
# O primeiro registro de temperatura foi de 35 graus.

# %%
temperaturas[0] = 35
print(temperaturas)
# Out:
# [35, 35, 39, 40, 42, 45, 38, 37]

# %%
temperaturas.append(39)
print(temperaturas)
# Out:
# [35, 40, 42, 45, 38, 37, 50, 39]

# %%
temperaturas.remove(39)
print(temperaturas)
# Out:
# [35, 40, 42, 45, 38, 37, 50]

# %%
temperaturas.remove(temperaturas[0])
print(temperaturas)
# Out:
# [40, 42, 45, 38, 37, 50]

# %%
compras = []
item1 = input("Digite o produto 1: ")
item2 = input("Digite o produto 2: ")
item3 = input("Digite o produto 3: ")
compras.append(item1)
print(compras)
compras.append(item2)
print(compras)
compras.append(item3)
print(compras)
# Out:
# ['Maçã']
# ['Maçã', 'Banana']
# ['Maçã', 'Banana', 'Melancia']
