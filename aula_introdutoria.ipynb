# %%
print("Treinamento de IA para Análise de Dados")
# Out:
# Treinamento de IA para Análise de Dados

# %%
print("Cassiano")
# Out:
# Cassiano

# %%
#Célua de Variáveis
nome = "Cassiano"
print("O seu nome é", nome)
# Out:
# O seu nome é Cassiano

# %%
print(f"O seu nome é {nome}")
# Out:
# O seu nome é Cassiano

# %%
nome = "Cassiano"
idade = 52
email = "cassianoroc@gmail.com"
profissao = "Autônomo"
print(f"O nome do usuário é {nome}, tem {idade} anos, possui o e-mail {email} e exerce a profissão {profissao}")
# Out:
# O nome do usuário é Cassiano, tem 52 anos, possui o e-mail cassianoroc@gmail.com e exerce a profissão Autônomo

# %%
#Comparadores
comparador = 10 > 5 #Retorna True se for maior
print(comparador)
# Out:
# True

# %%
comparador = 10 < 5 #Retorna True se for menor
print(comparador)
# Out:
# False

# %%
comparador = (10 == 10) #Retorna True se forem iguais
print(comparador)
# Out:
# True

# %%
comparador = (10 != 5) #Retorna True se forem diferentes
print(comparador)
# Out:
# True

# %%
temperatura = 50
if temperatura > 100:
    print("ALARME! O MOTOR ESTÁ FERVENDO!")
else:
    print("MOTOR EM TEMPERATURA IDEAL!")
# Out:
# MOTOR EM TEMPERATURA IDEAL!

# %%
power_bi = 32
ia_analise = 40
eletricista = 160
if power_bi > 40:
    print("O curso de Power BI precisa de Uniforme!")
else:
    print("O curso de Power BI NÃO precisa de Uniforme e precisa de CRACHÁ!")
if ia_analise > 40:
    print("O curso de IA e Análise de Dados precisa de Uniforme!")
else:
    print("O curso de IA e Análise de Dados NÃO precisa de Uniforme e precisa de CRACHÁ!")
if eletricista > 40:
    print("O curso de Eletricista Instalador precisa de Uniforme!")
else:
    print("O curso de Eletricista Instalador NÃO precisa de Uniforme e precisa de CRACHÁ!")
# Out:
# O curso de Power BI NÃO precisa de Uniforme e precisa de CRACHÁ!
# O curso de IA e Análise de Dados NÃO precisa de Uniforme e precisa de CRACHÁ!
# O curso de Eletricista Instalador precisa de Uniforme!

# %%
power_bi = 32
ia_dados = 40
eletric_inst = 160

# %%
if power_bi > 40:
    print("UNIFORME NECESSÁRIO!")
else:
    print("CRACHÁ NECESSÁRIO!")
# Out:
# CRACHÁ NECESSÁRIO!

# %%
if ia_dados > 40:
    print("UNIFORME NECESSÁRIO!")
else:
    print("CRACHÁ NECESSÁRIO!")
# Out:
# CRACHÁ NECESSÁRIO!

# %%
if eletric_inst > 40:
    print("UNIFORME NECESSÁRIO!")
else:
    print("CRACHÁ NECESSÁRIO!")
# Out:
# UNIFORME NECESSÁRIO!

# %%
#O comando input solicita a interação do usuário
nota = int(input("Digite a sua nota: "))
print(nota)
# Out:
# 10

# %%
if nota > 9:
    print("NOTA EXCELENTE \nPARABÉNS!")
elif nota > 7:
    print("NOTA BOA!")
elif nota > 5:
    print("NOTA REGULAR!")
else:
    print("REPROVADO!")
# Out:
# NOTA EXCELENTE
# PARABÉNS!

# %%
#APP de um banco virtual
nome_primario = input("Digite o seu nome primario: ")
print(f"Bem-vindo, {nome_primario}")
# Out:
# Bem-vindo, João

# %%
idade = int(input("Digite a sua idade: "))
print(idade)
print(type(idade))
# Out:
# 30
# <class 'int'>
